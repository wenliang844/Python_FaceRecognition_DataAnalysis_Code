# %%
from PIL import Image

# %%
cat = Image.open('./cat.jpg')
cat
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=261x253 at 0x2660C1537F0>

# %%
cat_data = np.array(cat)
cat_data
# Out:
# array([[[255, 251, 255],
#         [255, 251, 255],
#         [248, 255, 255],
#         ...,
#         [255, 245, 255],
#         [255, 250, 255],
#         [240, 254, 254]],
#
#        [[255, 250, 255],
#         [255, 254, 255],
#         [245, 255, 252],
#         ...,
#         [255, 249, 255],
#         [253, 245, 255],
#         [247, 255, 255]],
#
#        [[255, 248, 251],
#         [255, 254, 255],
#         [248, 255, 255],
#         ...,
#         [255, 253, 255],
#         [255, 254, 255],
#         [251, 255, 255]],
#
#        ...,
#
#        [[255, 254, 250],
#         [255, 255, 250],
#         [251, 255, 251],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 252, 251],
#         [255, 254, 251],
#         [248, 253, 247],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[253, 252, 250],
#         [254, 255, 253],
#         [249, 255, 253],
# ...

# %%
import numpy as np

# %%
cat_data.dtype
# Out:
# dtype('uint8')

# %%
cat_data.shape
# Out:
# (253, 261, 3)

# %%
cat_data.max()
# Out:
# 255

# %%
cat_data.min()
# Out:
# 0

# %%
cat2 = cat_data[:,:,::-1]

# %%
cat2
# Out:
# array([[[255, 251, 255],
#         [255, 251, 255],
#         [255, 255, 248],
#         ...,
#         [255, 245, 255],
#         [255, 250, 255],
#         [254, 254, 240]],
#
#        [[255, 250, 255],
#         [255, 254, 255],
#         [252, 255, 245],
#         ...,
#         [255, 249, 255],
#         [255, 245, 253],
#         [255, 255, 247]],
#
#        [[251, 248, 255],
#         [255, 254, 255],
#         [255, 255, 248],
#         ...,
#         [255, 253, 255],
#         [255, 254, 255],
#         [255, 255, 251]],
#
#        ...,
#
#        [[250, 254, 255],
#         [250, 255, 255],
#         [251, 255, 251],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[251, 252, 255],
#         [251, 254, 255],
#         [247, 253, 248],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[250, 252, 253],
#         [253, 255, 254],
#         [253, 255, 249],
# ...

# %%
Image.fromarray(cat2)
# Out:
# <PIL.Image.Image image mode=RGB size=261x253 at 0x13D9CD3F748>

# %%
Image.fromarray(cat_data[::5,::5])
# Out:
# <PIL.Image.Image image mode=RGB size=53x51 at 0x13DABC8CB70>

# %%
# 红录蓝   0,1,2   lu 红蓝   1,0,2
Image.fromarray(cat_data[:,:,[1,0,2]])
# Out:
# <PIL.Image.Image image mode=RGB size=261x253 at 0x13DABE8DDD8>

# %%
cat4 = cat_data[:,:,0]

# %%
Image.fromarray(cat4)
# Out:
# <PIL.Image.Image image mode=L size=261x253 at 0x13D9D3DB0B8>

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-a0d2faabd9e9> in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# D:\Coding\Anaconda3-5.3.1-Windows-x86_64\lib\site-packages\matplotlib\pyplot.py in <module>
#      34 from cycler import cycler
#      35 import matplotlib
# ---> 36 import matplotlib.colorbar
#      37 import matplotlib.image
#      38 from matplotlib import rcsetup, style
#
# D:\Coding\Anaconda3-5.3.1-Windows-x86_64\lib\site-packages\matplotlib\colorbar.py in <module>
#      42 import matplotlib.collections as collections
#      43 import matplotlib.colors as colors
# ---> 44 import matplotlib.contour as contour
#      45 import matplotlib.cm as cm
#      46 import matplotlib.gridspec as gridspec
#
# D:\Coding\Anaconda3-5.3.1-Windows-x86_64\lib\site-packages\matplotlib\contour.py in <module>
#      15 import matplotlib.collections as mcoll
# ...

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-a0d2faabd9e9> in <module>
# ----> 1 import matplotlib.pyplot as plt
#
# D:\Coding\Anaconda3-5.3.1-Windows-x86_64\lib\site-packages\matplotlib\pyplot.py in <module>
#      34 from cycler import cycler
#      35 import matplotlib
# ---> 36 import matplotlib.colorbar
#      37 import matplotlib.image
#      38 from matplotlib import rcsetup, style
#
# D:\Coding\Anaconda3-5.3.1-Windows-x86_64\lib\site-packages\matplotlib\colorbar.py in <module>
#      42 import matplotlib.collections as collections
#      43 import matplotlib.colors as colors
# ---> 44 import matplotlib.contour as contour
#      45 import matplotlib.cm as cm
#      46 import matplotlib.gridspec as gridspec
#
# D:\Coding\Anaconda3-5.3.1-Windows-x86_64\lib\site-packages\matplotlib\contour.py in <module>
#      15 import matplotlib.collections as mcoll
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(cat_data)

# %%
plt.imshow(cat_data[::-1])

# %%
plt.imshow(cat_data[::-5,::-5])

# %%
nd2 = [1,2,3,4,5,6,7,89,4]

# %%
nd2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 89, 4]

# %%
nd2.reshape(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-1a19687138c2> in <module>
# ----> 1 nd2.reshape(2)
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
np.split(nd2,indices_or_sections=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\lib\shape_base.py in split(ary, indices_or_sections, axis)
#     866     try:
# --> 867         len(indices_or_sections)
#     868     except TypeError:
#
# TypeError: object of type 'int' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-8f51f3a84e41> in <module>
# ----> 1 np.split(nd2,indices_or_sections=1)
#
# <__array_function__ internals> in split(*args, **kwargs)
#
# ~\AppData\Roaming\Python\Python37\site-packages\numpy\lib\shape_base.py in split(ary, indices_or_sections, axis)
#     868     except TypeError:
#     869         sections = indices_or_sections
# --> 870         N = ary.shape[axis]
#     871         if N % sections:
# ...

# %%
nd = [5,4,6,2,4,8,4,65,46,4,64,65,45,4,46,45,546,13,26,54,6541,3]
np.sort(nd)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5b5f4bdca763> in <module>
#       1 nd = [5,4,6,2,4,8,4,65,46,4,64,65,45,4,46,45,546,13,26,54,6541,3]
# ----> 2 np.sort(nd)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
nd = [5,4,6,2,4,8,4,65,46,4,64,65,45,4,46,45,546,13,26,54,6541,3]
np.sort(nd)
# Out:
# array([   2,    3,    4,    4,    4,    4,    4,    5,    6,    8,   13,
#          26,   45,   45,   46,   46,   54,   64,   65,   65,  546, 6541])

# %%
nd = np.random.randint(0,10000,size=100)

# %%
nd
# Out:
# array([1134, 2830, 4025, 8682, 3546,  422, 1918, 9709, 5448,   59, 4244,
#        5187, 3800, 6244, 3334, 6417, 7310, 8233, 5150, 9264, 7972, 4091,
#        3480, 3123, 5040,  288, 9777, 1050, 8463, 3238, 4307, 7450, 6360,
#        3321, 8613, 2848, 5504, 1630, 4561, 3817, 6647, 1309, 8652, 9417,
#        2471, 5800, 7685, 5839, 3262, 8495, 5714,  827, 4900, 3030, 9000,
#        1981, 3212, 4987, 3193, 1609, 8720, 8251, 9181, 9191, 1110, 1375,
#        2392, 7343,  875, 6539, 3272, 4895, 1245, 2076, 1525, 1369, 6940,
#        5604, 7257, 6609, 2857, 9091, 3386, 6875, 7919, 3861, 6078, 9849,
#         396, 6023, 7413, 2280, 5644, 3592, 5513, 5709, 7129, 8669, 9824,
#         349])

# %%
np.partition(nd,kth=5)[:5]
# Out:
# array([ 59, 288, 349, 396, 422])
