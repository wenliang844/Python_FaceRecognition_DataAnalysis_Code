# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
import pymysql

# %%
con = pymysql.Connection(host='127.0.0.1',port=3306,user = 'root',password='1234',database='edu1',charset='utf8')
con

# %%
sql = 'select * from t_user'
df = pd.read_sql(sql,con)
df
# Out:
#    id username password emp_id
# 0   1      abv      123   None
# 1   2      cwl      123   None
# 2   3      cwl      123   None
# 3   4      cwl      123   None
# 4   5     chen      123   None
# 5   6       c1     1234   None
# 6   7      thh     None   None
# 7   8        9     None   None
# 8   9     None     None   None
# 9  10        2     None   None

# %%
df.shape
# Out:
# (10, 4)

# %%
#写数据  操作:60%时间都是在处理数据,清洗数据,数据挖掘
#保存
df.to_sql('t_user_python1',con) #不支持
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Coding\Anaconda3-5.3.1-Windows-x86_64\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1377             else:
# -> 1378                 cur.execute(*args)
#    1379             return cur
#
# D:\Coding\Anaconda3-5.3.1-Windows-x86_64\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     145
# --> 146         query = self.mogrify(query, args)
#     147
#
# D:\Coding\Anaconda3-5.3.1-Windows-x86_64\lib\site-packages\pymysql\cursors.py in mogrify(self, query, args)
#     124         if args is not None:
# --> 125             query = query % self._escape_args(args, conn)
#     126
#
# TypeError: not all arguments converted during string formatting
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
from sqlalchemy import create_engine

# %%
#engine = create_engine('mysql+mysqldb://root@localhost:3306/blog')
engine = create_engine('mysql+pymysql://root:1234@localhost:3306/edu1') #?charset=uft8 编码会报错
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/edu1)

# %%
df.to_sql('t_user_python',engine)

# %%
df = DataFrame(np.random.randint(0,150,size=(6,3)),columns=['python','math','en'],index=list('asdfgh'))
df
# Out:
#    python  math   en
# a      67   142   43
# s      86   143   79
# d      71   105    3
# f     149    97   23
# g      59    92  131
# h       0   146   96

# %%
df = DataFrame(np.random.randint(0,150,size=(6,3)),columns=['python','math','en'],
               index=pd.MultiIndex.from_product([['张三','李四','王五'],['其中','期末']]))
df
# Out:
#        python  math   en
# 张三 其中       5   123   17
#    期末     120   118   23
# 李四 其中      68   110   21
#    期末     147     7   98
# 王五 其中      70    67   12
#    期末      38    84  113

# %%
df.loc['张三':'李四']
# Out:
#        python  math  en
# 张三 其中       5   123  17
#    期末     120   118  23
# 李四 其中      68   110  21
#    期末     147     7  98

# %%
df
# Out:
#        python  math   en
# 张三 其中       5   123   17
#    期末     120   118   23
# 李四 其中      68   110   21
#    期末     147     7   98
# 王五 其中      70    67   12
#    期末      38    84  113

# %%
df2 = DataFrame(np.random.randint(0,150,size=(3,3)),columns=['python','math','en'],
               index=['张三','李四','王五'])
df2
# Out:
#     python  math   en
# 张三     124   143  130
# 李四      87    65  135
# 王五     112     4   84

# %%
df2.loc['张三':'王五']
# Out:
#     python  math   en
# 张三     124   143  130
# 李四      87    65  135
# 王五     112     4   84

# %%
df2.iloc[1:2]
# Out:
#     python  math   en
# 李四      87    65  135

# %%
df2.iloc([0,])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-ad8c1aedaeda> in <module>
# ----> 1 df2.iloc([0,],axis=0)
#
# TypeError: __call__() got multiple values for argument 'axis'

# %%
df3 = df.sort_index() #多重索引排序后可以解决

# %%
df3.loc['张三':'王五']
# Out:
#        python  math   en
# 张三 其中       5   123   17
#    期末     120   118   23
# 李四 其中      68   110   21
#    期末     147     7   98
# 王五 其中      70    67   12
#    期末      38    84  113

# %%
#pandas数据处理    
#1.删除重复元素
df = DataFrame({'color':['red','blue','yellow','red'],'price':[10,15,20,10]})
df #有重复数据
# Out:
#     color  price
# 0     red     10
# 1    blue     15
# 2  yellow     20
# 3     red     10

# %%
df.drop_duplicates() #删除重复数据
# Out:
#     color  price
# 0     red     10
# 1    blue     15
# 2  yellow     20

# %%
#2.映射: 创建一个映射关系,字典就是一个映射关系, {key:value}
#replace函数:替换元素
df
# Out:
#     color  price
# 0     red     10
# 1    blue     15
# 2  yellow     20
# 3     red     10

# %%
df.replace({10:18,15:22,55:30},limit=1,inplace=True) #替换元素
df
# Out:
#     color  price
# 0     red     18
# 1    blue     22
# 2  yellow     20
# 3     red     18

# %%
df = DataFrame(np.random.randint(0,150,size=(100,3)),columns=['python','math','en'])
df
# Out:
#     python  math   en
# 0      100    82  140
# 1       92   112    9
# 2      113    50  112
# 3       64   143   84
# 4       25    62  133
# 5      126   122   75
# 6        1   124   29
# 7      137   111  141
# 8       83   128  143
# 9      124    66   26
# 10      40    60   43
# 11      14    82   84
# 12      15    48   89
# 13      25     0   35
# 14      87     7   66
# 15     148    52   68
# 16      77    59   23
# 17       0   124   65
# 18       6   118   89
# 19     138    35  113
# 20     117   136  118
# 21      43    35   88
# 22     100    47  137
# 23      14    66   74
# 24      79    93   20
# 25       6    36   83
# 26     115    80  127
# 27      23   118  149
# 28      16     0  124
# 29     112    37    2
# ..     ...   ...  ...
# 70       8   141  114
# 71      98   116   30
# 72     146    60   19
# 73     133    77   46
# 74     131    45   86
# 75      16    57  143
# 76      20    99  128
# 77       2   131  120
# 78      85   118   18
# ...

# %%
df3 = DataFrame(np.random.randint(0,150,size=(3,3)),columns=['python','math','en'])
df3
# Out:
#    python  math   en
# 0      66   136   35
# 1      77    86  145
# 2      37    61   20

# %%
#分数统一加10分
df['python'] = df['python'].map(lambda x :x+10)
df
# Out:
#     python  math   en
# 0      130    82  140
# 1      122   112    9
# 2      143    50  112
# 3       94   143   84
# 4       55    62  133
# 5      156   122   75
# 6       31   124   29
# 7      167   111  141
# 8      113   128  143
# 9      154    66   26
# 10      70    60   43
# 11      44    82   84
# 12      45    48   89
# 13      55     0   35
# 14     117     7   66
# 15     178    52   68
# 16     107    59   23
# 17      30   124   65
# 18      36   118   89
# 19     168    35  113
# 20     147   136  118
# 21      73    35   88
# 22     130    47  137
# 23      44    66   74
# 24     109    93   20
# 25      36    36   83
# 26     145    80  127
# 27      53   118  149
# 28      46     0  124
# 29     142    37    2
# ..     ...   ...  ...
# 70      38   141  114
# 71     128   116   30
# 72     176    60   19
# 73     163    77   46
# 74     161    45   86
# 75      46    57  143
# 76      50    99  128
# 77      32   131  120
# 78     115   118   18
# ...

# %%
def convert_level(x):
    if x<60:
        return '不及格'
    elif x<90:
        return '及格'
    else:
        return '优秀'
    
#加一列水平
df['level'] = df.mean(axis=1).map(convert_level)
df
# Out:
#     python  math   en level
# 0      130    82  140    优秀
# 1      122   112    9    及格
# 2      143    50  112    优秀
# 3       94   143   84    优秀
# 4       55    62  133    及格
# 5      156   122   75    优秀
# 6       31   124   29    及格
# 7      167   111  141    优秀
# 8      113   128  143    优秀
# 9      154    66   26    及格
# 10      70    60   43   不及格
# 11      44    82   84    及格
# 12      45    48   89    及格
# 13      55     0   35   不及格
# 14     117     7   66    及格
# 15     178    52   68    优秀
# 16     107    59   23    及格
# 17      30   124   65    及格
# 18      36   118   89    及格
# 19     168    35  113    优秀
# 20     147   136  118    优秀
# 21      73    35   88    及格
# 22     130    47  137    优秀
# 23      44    66   74    及格
# 24     109    93   20    及格
# 25      36    36   83   不及格
# 26     145    80  127    优秀
# 27      53   118  149    优秀
# 28      46     0  124   不及格
# 29     142    37    2    及格
# ..     ...   ...  ...   ...
# 70      38   141  114    优秀
# ...

# %%
df['java'] = df['python'].map(lambda x:x+10)

# %%
df.corr() #相关性系数
# Out:
#           python      math        en      java
# python  1.000000 -0.030622 -0.019008  1.000000
# math   -0.030622  1.000000  0.104169 -0.030622
# en     -0.019008  0.104169  1.000000 -0.019008
# java    1.000000 -0.030622 -0.019008  1.000000

# %%
df['chinese'] = df['python'].map(lambda x:x**0.5)

# %%
df
# Out:
#     python  math   en level  java    chinese
# 0      130    82  140    优秀   140  11.401754
# 1      122   112    9    及格   132  11.045361
# 2      143    50  112    优秀   153  11.958261
# 3       94   143   84    优秀   104   9.695360
# 4       55    62  133    及格    65   7.416198
# 5      156   122   75    优秀   166  12.489996
# 6       31   124   29    及格    41   5.567764
# 7      167   111  141    优秀   177  12.922848
# 8      113   128  143    优秀   123  10.630146
# 9      154    66   26    及格   164  12.409674
# 10      70    60   43   不及格    80   8.366600
# 11      44    82   84    及格    54   6.633250
# 12      45    48   89    及格    55   6.708204
# 13      55     0   35   不及格    65   7.416198
# 14     117     7   66    及格   127  10.816654
# 15     178    52   68    优秀   188  13.341664
# 16     107    59   23    及格   117  10.344080
# 17      30   124   65    及格    40   5.477226
# 18      36   118   89    及格    46   6.000000
# 19     168    35  113    优秀   178  12.961481
# ...

# %%
df.corr()
# Out:
#            python      math        en      java   chinese
# python   1.000000 -0.030622 -0.019008  1.000000  0.995292
# math    -0.030622  1.000000  0.104169 -0.030622 -0.027777
# en      -0.019008  0.104169  1.000000 -0.019008 -0.024952
# java     1.000000 -0.030622 -0.019008  1.000000  0.995292
# chinese  0.995292 -0.027777 -0.024952  0.995292  1.000000

# %%
df['python'].map(lambda x:x+10)
# Out:
# 0     140
# 1     132
# 2     153
# 3     104
# 4      65
# 5     166
# 6      41
# 7     177
# 8     123
# 9     164
# 10     80
# 11     54
# 12     55
# 13     65
# 14    127
# 15    188
# 16    117
# 17     40
# 18     46
# 19    178
# 20    157
# 21     83
# 22    140
# 23     54
# 24    119
# 25     46
# 26    155
# 27     63
# 28     56
# 29    152
#      ...
# 70     48
# 71    138
# 72    186
# 73    173
# 74    171
# 75     56
# 76     60
# 77     42
# 78    125
# 79    120
# 80    161
# 81     65
# 82    103
# 83    140
# 84     61
# 85     41
# 86     81
# 87     58
# 88    173
# 89    157
# 90    134
# 91     70
# 92    145
# 93     78
# 94    163
# 95     58
# 96    164
# 97    158
# 98     86
# 99     64
# Name: python, Length: 100, dtype: int64

# %%
df['chem'] = df['python'].map(lambda x:x/2)+ df['java'].map(lambda x:x/2)

# %%
df
# Out:
#     python  math   en level  java    chinese   chem
# 0      130    82  140    优秀   140  11.401754  135.0
# 1      122   112    9    及格   132  11.045361  127.0
# 2      143    50  112    优秀   153  11.958261  148.0
# 3       94   143   84    优秀   104   9.695360   99.0
# 4       55    62  133    及格    65   7.416198   60.0
# 5      156   122   75    优秀   166  12.489996  161.0
# 6       31   124   29    及格    41   5.567764   36.0
# 7      167   111  141    优秀   177  12.922848  172.0
# 8      113   128  143    优秀   123  10.630146  118.0
# 9      154    66   26    及格   164  12.409674  159.0
# 10      70    60   43   不及格    80   8.366600   75.0
# 11      44    82   84    及格    54   6.633250   49.0
# 12      45    48   89    及格    55   6.708204   50.0
# 13      55     0   35   不及格    65   7.416198   60.0
# 14     117     7   66    及格   127  10.816654  122.0
# 15     178    52   68    优秀   188  13.341664  183.0
# 16     107    59   23    及格   117  10.344080  112.0
# ...

# %%
s = df['python']

# %%
s.transform()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-29bf0f563555> in <module>
# ----> 1 s.transform()
#
# NameError: name 's' is not defined

# %%
df['price'] = np.random.randint(150,699,size=100)

# %%
df['count1'] = np.random.randint(2,10,size=100)

# %%
df['total'] = df.price * df.count1

# %%
df.head()
# Out:
#    python  math   en level  java    chinese   chem  price  count1  total
# 0     130    82  140    优秀   140  11.401754  135.0    583       9   5247
# 1     122   112    9    及格   132  11.045361  127.0    437       7   3059
# 2     143    50  112    优秀   153  11.958261  148.0    439       2    878
# 3      94   143   84    优秀   104   9.695360   99.0    505       5   2525
# 4      55    62  133    及格    65   7.416198   60.0    282       7   1974

# %%
df.rename({0:'A'},inplace=True)
df
# Out:
#     python  math   en level  java    chinese   chem  price  count1  total
# A      130    82  140    优秀   140  11.401754  135.0    583       9   5247
# 1      122   112    9    及格   132  11.045361  127.0    437       7   3059
# 2      143    50  112    优秀   153  11.958261  148.0    439       2    878
# 3       94   143   84    优秀   104   9.695360   99.0    505       5   2525
# 4       55    62  133    及格    65   7.416198   60.0    282       7   1974
# 5      156   122   75    优秀   166  12.489996  161.0    410       8   3280
# 6       31   124   29    及格    41   5.567764   36.0    554       9   4986
# 7      167   111  141    优秀   177  12.922848  172.0    190       5    950
# 8      113   128  143    优秀   123  10.630146  118.0    652       4   2608
# 9      154    66   26    及格   164  12.409674  159.0    269       3    807
# 10      70    60   43   不及格    80   8.366600   75.0    437       6   2622
# 11      44    82   84    及格    54   6.633250   49.0    639       8   5112
# ...

# %%
df = DataFrame(np.random.randn(10000,3),columns = ['red','green','blue'])
df
# Out:
#            red     green      blue
# 0     0.254497 -0.301285 -0.902065
# 1     1.023085  0.020141  1.275599
# 2    -1.480178  0.051401  0.667707
# 3    -0.450265 -0.246447 -1.706467
# 4     0.104213 -1.979931  1.022413
# 5     1.865005  0.935069 -1.656163
# 6    -1.860394 -0.519454  0.454258
# 7    -0.967426 -0.259622  0.486533
# 8    -0.578710  0.943180 -0.047863
# 9    -0.650456 -1.329882 -0.310405
# 10    0.636200  0.364155  0.181431
# 11   -0.442884 -0.410991  0.261922
# 12   -1.481433  0.064764  0.353433
# 13    0.636866  1.201731 -0.460641
# 14    0.429153 -1.676804 -0.412135
# 15    0.414667 -1.827173 -0.447836
# 16   -1.640459 -0.066667 -0.059376
# 17    1.557824  0.305708  0.533951
# 18    0.680577  0.586195  0.357828
# 19   -0.939739  1.705327 -0.102753
# 20   -0.196041  0.269281 -0.488839
# 21   -1.028893  0.192908  1.454071
# 22    1.116932 -1.430497 -2.064604
# 23    0.190538  0.161172  0.491630
# 24    0.141295  0.888808 -0.376390
# 25   -0.604744 -0.600387  0.213215
# ...

# %%
cond = df.abs() - df.mean() > 3*df.std() #把大于标准的异常值找到
cond.sum()
# Out:
# red      34
# green    30
# blue     22
# dtype: int64

# %%
cond = cond.any(axis=1) #大于标准的异常值
df[cond] #这是大于标准的异常值
# Out:
#            red     green      blue
# 60    1.111334  0.121993 -3.021541
# 68   -3.350640  0.300391 -0.828701
# 89   -2.349589  3.659010  1.643124
# 137  -1.298539 -1.231876 -3.432785
# 285  -3.718413 -1.635056  0.477120
# 895   3.182216  1.128460  0.779976
# 996   3.580634 -0.578940  1.666183
# 1191 -3.167737  0.066576 -1.903805
# 1346  0.395014 -3.155236 -0.101667
# 1366 -3.748877  0.216078  0.494556
# 1492 -3.239705 -0.490606  0.948956
# 1743 -0.359724 -0.426820 -3.706873
# 1852  1.539059  1.579227  3.306208
# 1866 -3.030719 -0.045289 -1.380542
# 2093 -0.309810 -3.105412  1.399913
# 2160 -0.629860 -2.549364 -3.268583
# 2181 -1.131161 -0.002700  3.396645
# 2184  0.367812 -3.228254  0.992418
# 2219  1.217004  0.451446  2.995167
# 2378  3.172663  1.091930 -0.866767
# 2555 -0.318833  3.588925 -0.994866
# 2565 -2.255522  3.052756 -0.121957
# 2587 -0.509423  3.377236  0.277346
# 2768  0.831461 -3.678272 -0.294075
# 2941 -3.169343 -0.384736  0.772564
# 2966  3.389767 -2.281019  0.450070
# ...

# %%
df2 = df.drop(labels=df[cond].index) #删除异常数据

# %%
df2.shape
# Out:
# (9914, 3)

# %%
9914/10000
# Out:
# 0.9914

# %%
df.sort_values(by = 'red',ascending=False) #排序
# Out:
#            red     green      blue
# 4367  3.854047  0.846746 -0.795904
# 6859  3.768144  0.598715 -0.266281
# 996   3.580634 -0.578940  1.666183
# 2966  3.389767 -2.281019  0.450070
# 9009  3.304459  0.709409 -0.439170
# 5514  3.299404 -1.227920  0.794663
# 4730  3.256272 -1.220957  0.608189
# 895   3.182216  1.128460  0.779976
# 2378  3.172663  1.091930 -0.866767
# 6941  3.158015  0.892382  0.745060
# 8066  3.110048  0.597962  1.555584
# 4629  3.026528  0.197013 -0.791367
# 4759  3.020816 -0.524151 -1.683207
# 566   2.938186 -1.395396 -0.181518
# 9284  2.931212  0.989436  0.306334
# 453   2.881080  0.413013 -0.134535
# 1459  2.876990 -2.347919  1.355298
# 9655  2.866543  1.499236 -1.919774
# 667   2.821356 -2.054422 -1.322844
# 9170  2.816334 -0.790457 -0.594788
# 894   2.814279 -1.069942 -1.510769
# 8657  2.812932  1.495141  1.503189
# 3058  2.803209  1.324000  0.049080
# 4795  2.785906  2.153021 -1.626962
# 7510  2.784869 -1.690926 -1.299314
# 8735  2.784859 -0.111905 -0.260764
# ...

# %%
df.shape
# Out:
# (10000, 3)

# %%
index = np.random.randint(0,10000,size = 1000)
index #有可能重复,随机的数字
# Out:
# array([9434, 4053, 5816, 3248,  541, 8052, 1725,  433, 8873,  338, 6535,
#        7816, 3744,  833, 2631, 7135, 6967, 6576, 4829, 3864, 7708, 7149,
#        7637, 9243, 6684,  443, 8996, 8136, 3302, 9340, 6415, 4676, 3283,
#        1651, 3166, 3622, 2758,  831, 9379, 6698,  820, 8386, 6468, 9194,
#        3694, 6156, 8030, 6651, 9414, 1888, 2504, 9346, 2188, 3046, 1636,
#        4589, 1617, 6963, 8332, 4959, 4516, 7216, 5291, 1387, 1650, 1886,
#        4906, 5597, 3801, 9707, 5412, 2262, 4971, 5102, 3848, 6999, 1468,
#        8723, 6476, 4560,  161,  912, 4789, 1929, 8987, 3102, 7231, 7580,
#        6975, 3894, 3218, 1006, 4445, 8107, 4647,  804, 9628, 7617, 5119,
#        8430, 3283, 3897, 2653,  439, 8123,  735, 7589, 6816, 5961,   12,
#        5890, 2687, 2914, 1917, 7769, 8478, 7808, 1852, 5823, 5246, 6332,
#        9402, 1100,  663, 3742, 3709, 5279,   41, 4711, 8430,  247, 6934,
#        1394, 8507, 9513, 5512, 8611, 3860, 1921,  538, 1610, 5335, 6620,
# ...

# %%
#随机抽样

# %%
df.take(index) #按照这个顺序去抽样 takle 拿
# Out:
#            red     green      blue
# 9434 -1.012611 -0.162500  0.847709
# 4053 -0.204479  1.214238 -1.193727
# 5816  0.984699  0.420982 -0.942560
# 3248 -0.294921 -1.504947  0.238837
# 541   0.572105  0.651277  0.934755
# 8052  0.711729 -1.178075  1.381616
# 1725 -2.448096 -1.752877 -0.126703
# 433   0.520844 -0.925359  1.157865
# 8873 -0.687215 -0.226970 -1.437434
# 338   1.386447 -0.092278 -0.055398
# 6535 -1.259960 -0.145434  0.719319
# 7816 -0.592923  0.151726  1.460227
# 3744 -1.116974  0.350415  0.115031
# 833   1.907523 -0.807099 -0.099804
# 2631  1.129426  0.625831  1.428390
# 7135 -0.563583 -0.466504 -2.070052
# 6967 -0.039984 -0.641503 -1.640903
# 6576 -0.650072 -0.964526 -0.844828
# 4829  0.125564 -0.014070  0.106442
# 3864  0.973411 -0.278560 -0.394405
# 7708 -0.673870  0.053861  2.140489
# 7149 -0.701181 -0.244465  0.312201
# 7637  0.603266 -0.698883 -0.474120
# 9243  0.549758 -0.221676 -1.605739
# 6684 -2.282682  0.293868  0.293363
# 443  -0.134189  1.819163 -0.753986
# ...

# %%
#随机抽样
